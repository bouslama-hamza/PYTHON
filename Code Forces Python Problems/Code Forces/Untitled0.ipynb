# %% [markdown]
# Problem 1:

# %%
class Test:
  lasten = []

  #get the values
  def __init__(self,numbers):
    self.numbers = numbers

  #starting the calculation
  def find_number(self):
    number_of_test = [(j,i) for i in range(1,len(self.numbers)+1) for j in range(1,i) if not i == j]
    for m in range(len(number_of_test)):
      self.lasten.append([y for i,y in enumerate(x) if number_of_test[m][0] <= i+1 <= number_of_test[m][1]])
      #return the latest result
    return max(max(self.lasten[i])*min(self.lasten[i]) for i in range(len(self.lasten)))

#geting values
x = list(map(int,input("Enter a multiple value (space bettwen):").split()))
Test(x).find_number()

# %% [markdown]
# Problem 2 :

# %%
a = list(map(int, input().split()))
m = [a.index(min(a))+1,a.index(max(a))+1,a[::-1].index(min(a))+1,a[::-1].index(max(a))+1]
print(sum(m.pop(m.index(min(m))) for i in range(2)))
