# %% [markdown]
# # PYTHON INSTITUE

# %% [markdown]
# how to write and run simple Python programs;
#
# what Python literals, operators, and expressions are;
#
# what variables are and what are the rules that govern them;
#
# how to perform basic input and output operations.

# %%
print("Hisssssss...")
print("My name is", "Python.")
print("Monty Python.")
#keyword argument
print("My name is", "Python.", end=" ")
print("Monty Python.")
print("My", "name", "is", "Monty", "Python.", sep="-")
#diffrent between them
print("My", "name", "is", sep="_", end="*")
print("Monty", "Python.", sep="*", end="*\n")
#exercice
print("Programming","Essentials","in",sep="***" , end="...")
print("Python")
print("     *\n","   * *\n","  *    *\n"," *      *\n","***    ***\n","  *    *\n","  *    *\n",end="   ******\n")
# Integers: octal and hexadecimal numbers
print(0o123)
print(0x123)
print('I\'m Monty Python.')
print('"I\'m"\n','""learning""\n','"""Python"""')

# %%
#boleen Value
print(True > False)
print(True < False)
#basid operation
print(2 ** 3)
print(2 ** 3.)
print(2. ** 3)
print(2. ** 3.)
print((5 * ((25 % 13) + 100) / (2 * 13)) // 2)

# %%
# start using variable
var = 1
print(var)
# use many variable
var = 1
account_balance = 1000.0
client_name = 'John Doe'
print(var, account_balance, client_name)
print(var)
# text and variable
var = "3.8.5"
print("Python version: " + var)
#Solving simple mathematical problems 
a = 3.0
b = 4.0
c = (a ** 2 + b ** 2) ** 0.5
print("c =", c)
#simple exercice
john = 3
mary = 5
adam = 6
# print the value
print(john,mary,adam)
# use operation
total_apples = john + mary + adam
print(total_apples)
#use text with variable
print("number of apples : " ,total_apples)

# %%
#Shortcut operators
x *= 2
sheep += 1
i += 2 * j
var /= 2
rem %= 10
j -= (i + var + rem)
#simple tasc
kilometers = 12.25
miles = 7.38

miles_to_kilometers = miles * 1.61
kilometers_to_miles = kilometers / 1.61

print(miles, "miles is", round(miles_to_kilometers, 2), "kilometers")
print(kilometers, "kilometers is", round(kilometers_to_miles, 2), "miles")

#second simple tasc
Euro = 5.56
USA = 3.23

Euro_to_us = Euro * 0.85
USA_to_euro = USA / 0.85

print(Euro , "Euro Eqaul " , round(Euro_to_us) ,"USA")
print(USA , "USA Eqaul " , round(USA_to_euro) ,"Euro")

# %%
#simple arretmetique operation
x =  0
x = float(x)
y = (3*(x**3)) - (2*(x**2)) + (3*x) - 1
print("y =", y)

# %%
# be Famuliare with comment
#this program computes the number of seconds in a given number of hours
# this program has been written two days ago

a = 2 # number of hours
seconds = 3600 # number of seconds in 1 hour
print("Hours: ", a) #printing the number of hours
print("Seconds in Hours: ", a * seconds) # printing the number of seconds in a given number of hour
#here we should also print "Goodbye"
print("Goodbye")
#this is the end of the program that computes the number of seconds in 3 hour
a = 3
print("Seconds in Hours: ", a * seconds)

# %%
#The input() function
print("Tell me anything...")
anything = input()
print("Hmm...", anything, "... Really?")
#type casting
anything = float(input("Enter a number: "))
something = anything ** 2.0
print(anything, "to the power of 2 is", something)

# %%
#String operators - introduction
fnam = input("May I have your first name, please? ")
lnam = input("May I have your last name, please? ")
print("Thank you.")
print("\nYour name is " + fnam + " " + lnam + ".")
#replaction
print("+" + 10 * "-" + "+")
print(("|" + " " * 10 + "|\n") * 5, end="")
print("+" + 10 * "-" + "+")
#Type conversion: str()
leg_a = float(input("Input first leg length: "))
leg_b = float(input("Input second leg length: "))
print("Hypotenuse length is " + str((leg_a**2 + leg_b**2) ** .5))

# %%
#simmple Task
# input a float value for variable a here
f_number = float(input("Giv me the first number : "))
# input a float value for variable b here
s_number = float(input("Giv me the second number : "))
# output the result of addition here
print("addition : ",f_number + s_number)
# output the result of subtraction here
print("substraction : ",f_number - s_number)
# output the result of multiplication here
print("multiplication : ",f_number * s_number)
# output the result of division here
print("division : ",f_number / s_number)
print("\nThat's all, folks!")

# %%
#simple input task
x = float(input("Enter value for x: "))
# Write your code here.
y = 1/(x+(1/(x+(1/(x+(1/x))))))
print("y =", y)

# %%
hour = int(input("Starting time (hours): "))
mins = int(input("Starting time (minutes): "))
dura = int(input("Event duration (minutes): "))
# Write your code here.
l_result = (hour*60) + mins + dura #Change time to minutes
n_hour = l_result // 60 #new hour
n_min = l_result % 60 #new minutes
#Final result
print(n_hour,":",n_min)

# %%
print(1/2+3 // 3+4 **2)
