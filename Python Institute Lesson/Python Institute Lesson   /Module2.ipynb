# %% [markdown]
# #Python Institue

# %% [markdown]
# the Boolean data type;
#
# relational operators;
# making decisions in Python (if, if-else, if-elif,else)
#
# how to repeat code execution using loops (while, for)
#
# how to perform logic and bitwise operations in Python;
#
# lists in Python (constructing, indexing, and slicing; content manipulation)
#
# how to sort a list using bubble-sort algorithms;
#
# multidimensional lists and their applications.

# %% [markdown]
# **I _ Comparison**

# %% [markdown]
# 1 _ Comparison: equality operato

# %%
print(2 == 2) #True
print(2 == 2.0) #True
print(2 == 1) #False

# %% [markdown]
# 2 _ Inequality: the not equal to operator (!=)

# %%
var = 0  # Assigning 0 to var
print(var != 0)

var = 1  # Assigning 1 to var
print(var != 0)

# %% [markdown]
# 3 _ Comparison operators: greater than , gt or equalm, less than , lt or equal :

# %%
print(5 > 6) #False
print(5 >= 5) #False
print(5 < 6 ) #True
print(5 <= 4) #False

# %% [markdown]
# 4 _ Simple Test

# %%
number = int(input("Give a Number : ")) #get a number from the user
print(number >= 100) #the result

# %% [markdown]
# **II _ Conditions and conditional execution**

# %% [markdown]
# 1 _ Conditional execution: the if statement

# %%
if sheep_counter >= 120: # Evaluate a test expression
    sleep_and_dream() # Execute if test expression is True

# %%
if sheep_counter >= 120:
    make_a_bed()
    take_a_shower()
    sleep_and_dream()
feed_the_sheepdogs()

# %% [markdown]
# 2 _ Conditional execution: the if-else statement

# %%
if true_or_false_condition:
    perform_if_condition_true
else:
    perform_if_condition_false

# %%
if the_weather_is_good:
    go_for_a_walk()
else:
    go_to_a_theater()
have_lunch()

# %%
if the_weather_is_good:
    if nice_restaurant_is_found:
        have_lunch()
    else:
        eat_a_sandwich()
else:
    if tickets_are_available:
        go_to_the_theater()
    else:
        go_shopping()

# %% [markdown]
# 3 _ The elif statement

# %%
if the_weather_is_good:
    go_for_a_walk()
elif tickets_are_available:
    go_to_the_theater()
elif table_is_available:
    go_for_lunch()
else:
    play_chess_at_home()

# %% [markdown]
# 4 _ Analyzing code samples

# %%
# Read two numbers
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))

# Choose the larger number
if number1 > number2:
    larger_number = number1
else:
    larger_number = number2

# Print the result
print("The larger number is:", larger_number)

# %%
# Read two numbers
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))

# Choose the larger number
if number1 > number2: larger_number = number1
else: larger_number = number2

# Print the result
print("The larger number is:", larger_number)

# %%
# Read three numbers
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
number3 = int(input("Enter the third number: "))

# We temporarily assume that the first number
# is the largest one.
# We will verify this soon.
largest_number = number1

# We check if the second number is larger than current largest_number
# and update largest_number if needed.
if number2 > largest_number:
    largest_number = number2

# We check if the third number is larger than current largest_number
# and update largest_number if needed.
if number3 > largest_number:
    largest_number = number3

# Print the result
print("The largest number is:", largest_number)

# %% [markdown]
# 5 _ the Max Funtion

# %%
# Read three numbers.
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
number3 = int(input("Enter the third number: "))

# Check which one of the numbers is the greatest
# and pass it to the largest_number variable.

largest_number = max(number1, number2, number3)

# Print the result.
print("The largest number is:", largest_number)

# %% [markdown]
# 6 _ simple test

# %%
need_word = input() #get the word from the user
# use the conditional option
if need_word == 'Spathiphyllum':
    print("Yes - Spathiphyllum is the best plant ever!")
elif need_word == 'spathiphyllum':
    print("No, I want a big Spathiphyllum!")
else:
    print("Spathiphyllum! Not ",need_word,"!")

# %%
income = float(input("Enter the annual income: "))

#simplify the calculation
big_income = ((85528*32) / 100)
small_income = 556.2

#start the condition
if income > 85528 :
    tax = (((income * 32) / 100) - big_income) + 14839
    if tax <= 0 : tax = 0.0
elif income < 85528:
    tax = ((income * 18) / 100) - small_income
    if tax <= 0 : tax = 0.0
    
#git the result
tax = round(tax, 0)
print("The tax is:", tax, "thalers")

# %%
year = int(input("Enter a year: "))

#start the condition statement
if year > 1582:
    if year % 4 != 0 :
        print("Common year")
    elif year % 100 != 0:
        print("Leap year")
    elif year % 400 != 0:
        print("Common year")
    else :
        print("Leap Year")
else:
    print("Not within the Gregorian calendar period")

# %% [markdown]
# **III _ Looping your code **

# %% [markdown]
# 1 _ using while

# %%
# Store the current largest number here.
largest_number = -999999999

# Input the first value.
number = int(input("Enter a number or type -1 to stop: "))

# If the number is not equal to -1, continue.
while number != -1:
    # Is number larger than largest_number?
    if number > largest_number:
        # Yes, update largest_number.
        largest_number = number
    # Input the next number.
    number = int(input("Enter a number or type -1 to stop: "))

# Print the largest number.
print("The largest number is:", largest_number)

# %% [markdown]
# 2 _ simple test

# %%
secret_number = 777

print(
"""
+================================+
| Welcome to my game, muggle!    |
| Enter an integer number        |
| and guess what number I've     |
| picked for you.                |
| So.... |
+================================+
""")
player_number = int(input("what is the secret number ?: "))
while player_number != secret_number :
    print("Ha ha! You're stuck in my loop!")
    player_number = int(input("what is the secret number ?: "))
    
print("Well done, muggle! You are free now.")

# %% [markdown]
# 2 _ using For

# %%
for i in range(10):
    print("The value of i is currently", i)

# %%
for i in range(2, 8):
    print("The value of i is currently", i)

# %%
for i in range(2, 1):
    print("The value of i is currently", i)

# %%
import time
# Write a for loop that counts to five.
for i in range(5):
    # Body of the loop - print the loop iteration number and the word "Mississippi".
    print(i+1,"Mississippi")
    # Body of the loop - use: time.sleep(1)
    time.sleep(1)
# Write a print function with the final message.
print("Ready or not, here I come!")

# %% [markdown]
# 3 _ syntactic candy

# %%
print("The break instruction:")
for i in range(1, 6):
    if i == 3:
        break
    print("Inside the loop.", i)
print("Outside the loop.")

# %%
print("\nThe continue instruction:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Inside the loop.", i)
print("Outside the loop.")

# %% [markdown]
# 4 _ simple test

# %%
need_word = "chupacabra" # the need word to exit the loop
giving_word = str(input("Giv me your word : "))
#starting the loop option
while True:
    if giving_word == need_word:
        break
    giving_word = str(input("Giv me your word : "))
#exit the loop
print("You've successfully left the loop.")

# %%
# Prompt the user to enter a word
user_word = str(input("Giv me your word : "))
# and assign it to the user_word variable.
user_word = user_word.upper()
for letter in user_word:
    if letter in 'AEIO':
        continue
    print(letter)

# %%
word_without_vowels = ""
# Prompt the user to enter a word
user_word = str(input("Giv me your word : "))
# and assign it to the user_word variable.
user_word = user_word.upper()
for letter in user_word:
    # Complete the body of the loop.
    if letter in 'AEIO':
        continue
    word_without_vowels += letter
# Print the word assigned to word_without_vowels.
print(word_without_vowels)

# %% [markdown]
# 5 _
# The while loop and the else branch

# %%
i = 1
while i < 5:
    print(i)
    i += 1
else:
    print("else:", i)

# %%
for i in range(5):
    print(i)
else:
    print("else:", i)

# %% [markdown]
# 6 _ Final Test

# %%
blocks = int(input("Enter the number of blocks: "))
height = 0
#
for i in range(1 , blocks+1):
  if blocks < i :
    break
  blocks -= i
  height +=1
#	
print("The height of the pyramid:", height)

# %%
c0 = int(input("Giv me a number : "))
step = 0
while c0 != 1:
    if c0 % 2 ==0:
        c0 //= 2
        step += 1
    else:
        c0 = (c0 * 3) + 1
        step += 1
    print(c0)
print("steps =",step)

# %% [markdown]
# 7 _ Binary left shift and binary right shift

# %%
var = 17
var_right = var >> 2
var_left = var << 2
print(var, var_left, var_right)
# Out:
# 17 68 4

# %% [markdown]
# **IV _Why do we need lists?**

# %% [markdown]
# 1 _ Indexing lists

# %%
numbers = [10, 5, 7, 2, 1]
print("Original list content:", numbers)  # Printing original list content.

numbers[0] = 111
print("New list content: ", numbers)  # Current list content.

# %%
numbers = [10, 5, 7, 2, 1]
print("Original list content:", numbers)  # Printing original list content.

numbers[0] = 111
print("\nPrevious list content:", numbers)  # Printing previous list content.

numbers[1] = numbers[4]  # Copying value of the fifth element to the second.
print("New list content:", numbers)  # Printing current list content.

# %% [markdown]
# 2 _ Accessing list content

# %%
print(numbers[0]) # Accessing the list's first element.

# %% [markdown]
# 3 _ The len() function

# %%
numbers = [10, 5, 7, 2, 1]
print("Original list content:", numbers)  # Printing original list content.

numbers[0] = 111
print("\nPrevious list content:", numbers)  # Printing previous list content.

numbers[1] = numbers[4]  # Copying value of the fifth element to the second.
print("Previous list content:", numbers)  # Printing previous list content.

print("\nList length:", len(numbers))  # Printing the list's length.

# %% [markdown]
# 4 _ Removing elements from a list

# %%
numbers = [10, 5, 7, 2, 1]
print("Original list content:", numbers)  # Printing original list content.

numbers[0] = 111
print("\nPrevious list content:", numbers)  # Printing previous list content.

numbers[1] = numbers[4]  # Copying value of the fifth element to the second.
print("Previous list content:", numbers)  # Printing previous list content.

print("\nList's length:", len(numbers))  # Printing previous list length.

###

del numbers[1]  # Removing the second element from the list.
print("New list's length:", len(numbers))  # Printing new list length.
print("\nNew list content:", numbers)  # Printing current list content.

###

# %% [markdown]
# 5 _ Negative indices

# %%
print(numbers[-1])

# %% [markdown]
# 6 _ simple task

# %%
hat_list = [1, 2, 3, 4, 5] # This is an existing list of numbers hidden in the hat.
# Step 1: write a line of code that prompts the user
# to replace the middle number with an integer number entered by the user.
hat_list[len(hat_list) // 2] = int(input("Give A Number : "))
# Step 2: write a line of code that removes the last element from the list.
del hat_list[-1]
# Step 3: write a line of code that prints the length of the existing list.
print(len(hat_list))
# Last Result
print(hat_list)

# %% [markdown]
# 7 _ Adding elements to a list: append() and insert()

# %%
numbers = [111, 7, 2, 1]
print(len(numbers))
print(numbers)

###

numbers.append(4)

print(len(numbers))
print(numbers)

###

numbers.insert(0, 222)
print(len(numbers))
print(numbers)

#

# %% [markdown]
# 8 _ Adding elements to a list: continued

# %%
my_list = []  # Creating an empty list.

for i in range(5):
    my_list.append(i + 1)

print(my_list)
# diffirent
my_list = []  # Creating an empty list.

for i in range(5):
    my_list.insert(0, i + 1)

print(my_list)

# %% [markdown]
# 9 _ Making use of lists

# %%
my_list = [10, 1, 8, 3, 5]
total = 0

for i in range(len(my_list)):
    total += my_list[i]

print(total)

# %% [markdown]
# 10 _ Lists in action

# %%
my_list = [10, 1, 8, 3, 5]

my_list[0], my_list[4] = my_list[4], my_list[0]
my_list[1], my_list[3] = my_list[3], my_list[1]

print(my_list)

# %% [markdown]
# 11 _ simple task

# %%
# step 1
beatles = []
print("Step 1:", beatles)

# step 2
beatles.append('John')
beatles.append('Lennon')
beatles.append('Paul McCartney')
beatles.append('George Harrison')
print("Step 2:", beatles)

# step 3
for i in ['Stu Sutcliffe' ,'Pete Best']:
    beatles.append(i)
print("Step 3:", beatles)

# step 4
del beatles[4]
del beatles[4]
print("Step 4:", beatles)

# step 5
beatles.insert(0 ,'Ringo Starr')
print("Step 5:", beatles)

# testing list legth
print("The Fab", len(beatles))

# %% [markdown]
# 12 _ Sorting a list

# %%
my_list = [8, 10, 6, 2, 4]  # list to sort

for i in range(len(my_list) - 1):  # we need (5 - 1) comparisons
    if my_list[i] > my_list[i + 1]:  # compare adjacent elements
        my_list[i], my_list[i + 1] = my_list[i + 1], my_list[i]  # If we end up here, we have to swap the elements.

# %%
my_list = [8, 10, 6, 2, 4]  # list to sort
swapped = True  # It's a little fake, we need it to enter the while loop.

while swapped:
    swapped = False  # no swaps so far
    for i in range(len(my_list) - 1):
        if my_list[i] > my_list[i + 1]:
            swapped = True  # a swap occurred!
            my_list[i], my_list[i + 1] = my_list[i + 1], my_list[i]

print(my_list)

# %% [markdown]
# 13 _ The bubble sort - interactive version

# %%
my_list = [8, 10, 6, 2, 4]
my_list.sort()
print(my_list)

# %%
#sort
lst = [5, 3, 1, 2, 4]
print(lst)

lst.sort()
print(lst)  # outputs: [1, 2, 3, 4, 5]
#reverse
lst = [5, 3, 1, 2, 4]
print(lst)

lst.reverse()
print(lst)  # outputs: [4, 2, 1, 3, 5]

# %% [markdown]
# 14 _ Powerful slices

# %%
list_1 = [1]
list_2 = list_1[:]
list_1[0] = 2
print(list_2)

# %%
# Copying some part of the list.
my_list = [10, 8, 6, 4, 2]
new_list = my_list[1:3]
print(new_list)

# %% [markdown]
# 15 _ Slices: continued

# %%
my_list = [10, 8, 6, 4, 2]
new_list = my_list[:3]
print(new_list)

# %% [markdown]
# 16 _ The in and not in operators

# %%
my_list = [0, 3, 12, 8, 2]

print(5 in my_list)
print(5 not in my_list)
print(12 in my_list)

# %% [markdown]
# 17 _ simple Task

# %%
my_list = [1, 2, 4, 4, 1, 4, 2, 6, 2, 9]
new_list = []
# Write your code here.
for i in my_list :
    if i not in new_list:
        new_list.append(i)
#
print("The list with unique elements only:")
print(new_list)

# %% [markdown]
# 18_ Lists in lists

# %%
row = [WHITE_PAWN for i in range(8)]
squares = [x ** 2 for x in range(10)]
twos = [2 ** i for i in range(8)]
odds = [x for x in squares if x % 2 != 0 ]

# %% [markdown]
# 19 _ Lists in lists: two-dimensional arrays

# %%
board = [[EMPTY for i in range(8)] for j in range(8)]

# %% [markdown]
# 20 _ Three-dimensional arrays

# %%
rooms = [[[False for r in range(20)] for f in range(15)] for t in range(3)]
